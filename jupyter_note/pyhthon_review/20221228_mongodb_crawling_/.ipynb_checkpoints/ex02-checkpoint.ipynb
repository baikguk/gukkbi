# %%
'''
공공 데이터 포털 API 이용하기

https://www.data.go.kr

1) 회원가입
2) 로그인
3) API 활용 신청하기
4) 발급받은 인증키를 사용해서 API 활용하기

로그인해서
미세먼지 입력하고 enter !

한국환경공단_에어코리아_미세먼지 경보 발령 현황 클릭

활용신청 클릭

마이페이지 > 오픈API > 개발계정 >

[승인] 한국환경공단_에어코리아_미세먼지 경보 발령 현황 클릭

d) 요청/응답 메시지 예제
요청메시지
http://apis.data.go.kr/B552584/UlfptcaAlarmInqireSvc/getUlfptcaAlarmInfo?year=2020&pageNo=1&numOfRows=100&returnType=xml&serviceKey=서비스키

일반 인증키 (Encoding)	

일반 인증키 (Decoding)	



마이페이지 > 오픈API > 개발계정 > 개발계정 상세보기 > 

기본정보

데이터명	한국환경공단_에어코리아_미세먼지 경보 발령 현황 [상세설명]  <-- 클릭 !!!

아랫쪽에 있는
샘플코드 > python 클릭

# Python3 샘플 코드 #
import requests

url = 'http://apis.data.go.kr/B552584/UlfptcaAlarmInqireSvc/getUlfptcaAlarmInfo'
params ={'serviceKey' : '서비스키', 'returnType' : 'xml', 'numOfRows' : '100', 'pageNo' : '1', 'year' : '2020', 'itemCode' : 'PM10' }

response = requests.get(url, params=params)
print(response.content)

'''

# %% [markdown]
# 한국환경공단_에어코리아_미세먼지 경보 발령 현황
# 상세설명 페이지에서 요청변수 / 출력결과 확인하기
#
# 요청변수(Request Parameter)
#
# ![Image Description](request_parameter.png)
#
# 출력결과(Response Element)
# ![Image Description](response_element.png)

# %%
# Python3 샘플 코드 #
import requests

# 마이페이지 > 오픈API > 개발계정 > 개발계정 상세보기 에 있는 
# 일반 인증키 (Decoding)  복사 붙여넣기
service_key = ''
url = 'http://apis.data.go.kr/B552584/UlfptcaAlarmInqireSvc/getUlfptcaAlarmInfo'
params ={'serviceKey' : service_key, 
         'returnType' : 'xml', 
         'numOfRows' : '100', 
         'pageNo' : '1', 
         'year' : '2020', 
         'itemCode' : 'PM10' }

response = requests.get(url, params=params)
print(response.content)

# %%
print(response.text)

# %% [markdown]
# 한국환경공단_에어코리아_대기오염정보 검색 > 활용신청
#
# 한국환경공단_에어코리아_대기오염정보
# 상세설명 페이지에서 요청변수 확인하기 / 출력결과 확인하기
#
# 요청변수(Request Parameter)
#
# ![Image Description](request_parameter_2.png)
#
# 출력결과(Response Element)
# ![Image Description](response_element02.png)

# %%
'''
한국환경공단_에어코리아_대기오염통계 현황

일반 인증키 (Encoding)	

일반 인증키 (Decoding)	



http://apis.data.go.kr/B552584/ArpltnStatsSvc/getCtprvnMesureLIst?itemCode=PM10&dataGubun=HOUR&pageNo=1&numOfRows=100&returnType=xml&serviceKey=서비스키


'''
1

# %%
import requests

serviceKey = '일반 인증키 (Encoding)'
url = f'http://apis.data.go.kr/B552584/ArpltnStatsSvc/getCtprvnMesureLIst?itemCode=PM10&dataGubun=HOUR&pageNo=1&numOfRows=100&returnType=json&serviceKey={serviceKey}'

response = requests.get(url)
print(response.content)
print('-' * 70)
print(response.text)

# %%
'''
한국환경공단_에어코리아_대기오염정보

        so2Grade	아황산가스 지수 
        coFlag		일산화탄소 플래그
        khaiValue	통합대기환경수치
        so2Value	아황산가스 평균농도
        coValue		일산화탄소 평균농도
        pm10Flag	미세먼지 플래그
        pm10Value	미세먼지 평균농도
        o3Grade		오존 평균농도
        khaiGrade	통합대기환경 지수
        no2Flag		이산화질소 플래그
        no2Grade	이산화질소 지수
        o3Flag		오존 플래그
        so2Flag		아황산가스 플래그
        no2value	이산화질소 평균농도
        pm10grade	미세먼지 지수
        o3value		오존 평균농도

일반 인증키 (Encoding)	

일반 인증키 (Decoding)	



XML - Extensible Markup Language

특정 목적에 따라서 data 를 tag로 감싸서 markup 하는 format
MarkUp 언어는 tag 들을 이용해서 data 의 구조를 표현하는 언어임

XML 의 기본구조
  <태그 속성='속성값'>내용(content)</태그>
-  태그와 속성은 임의로 정해서 사용할 수 있음
'''

# %%
'''
http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty?stationName=종로구&dataTerm=month&pageNo=1&numOfRows=100&returnType=xml&serviceKey=서비스키
'''

from bs4 import BeautifulSoup
import requests
import warnings
warnings.filterwarnings('ignore')

'''
일반 인증키 (Encoding)	
'''

serviceKey = '일반 인증키 (Encoding)'
url = f'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty?stationName=종로구&dataTerm=month&pageNo=1&numOfRows=100&returnType=xml&serviceKey={serviceKey}'

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# item 이라는 tag 에 있는 data 가져오기
data = soup.find_all('item')
# print('item 개수 :',len(list(data)),'개')

for item in data:
    # print(item)
    # print(item.get_text())
    datatime  = item.find('datatime')
    pm10grade = item.find('pm10grade')
    print(datatime.get_text(),pm10grade.get_text())

# %%
print(response.text)
